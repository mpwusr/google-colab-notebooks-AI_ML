# %% [markdown]
# # Operating system calls
#
# It's possible to use python to perform command line calls
#
# We can do this with the os module

# %%
import os

# %% [markdown]
# ## name of operating system
#
# We can get the operating system we're working on
#
# 1. nt is windows
# 2. posix is all unix based systems (Mac, Linux, ...)

# %%
print(os.name)

my_os = os.name
# Out:
# posix

# %% [markdown]
# ## working directory

# %%
os.getcwd()
# Out:
# '/content'

# %%
print(os.getcwd())
# Out:
# /content

# %% [markdown]
# ## contents of directory

# %%
os.listdir('.')
# Out:
# ['.config', 'new_dir2', 'sample_data']

# %%
os.listdir('./sample_data')
# Out:
# ['README.md',
#  'anscombe.json',
#  'california_housing_test.csv',
#  'california_housing_train.csv',
#  'mnist_test.csv',
#  'mnist_train_small.csv']

# %% [markdown]
# ## make and rename directory

# %%
os.mkdir('./new_dir')

# %%
os.rename('./new_dir','./new_dir2')

# %% [markdown]
# ## create and edit file

# %%
file = open('./new_dir/myTXTfile.txt','w')
file.write('hello\n')
file.write('world!')
file.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-37a1289dd787> in <cell line: 1>()
# ----> 1 file = open('./new_dir/myTXTfile.txt','w')
#       2 file.write('hello\n')
#       3 file.write('world!')
#       4 file.close()
#
# FileNotFoundError: [Errno 2] No such file or directory: './new_dir/myTXTfile.txt'
