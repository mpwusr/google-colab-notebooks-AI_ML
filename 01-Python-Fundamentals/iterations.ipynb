# %% [markdown]
# # *Google Colab notebook for beginning python*

# %% [markdown]
# ## *1. Iterations*

# %% [markdown]
# ### *1.1: For loop syntax*

# %%
for some_variable in range_of_values:
  loop_body
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-780d14f9fd19> in <cell line: 1>()
# ----> 1 for some_variable in range_of_values:
#       2   loop_body
#
# NameError: name 'range_of_values' is not defined

# %%
for i in range(0, 100):
    print(i)

# %%
for i in range(100):
    print(i)

# %%
# n = 12
n = int(input("Printing a pyramid of width: "))
for i in range(1, n + 1):
# Print leading spaces
  for j in range(n - i):
    print(" ", end="")
    # Print asterisks for the current row
  for k in range(1, 2*i):
    print("*", end="")
  print()
# Out:
# Printing a pyramid of width: 35
#                                   *
#                                  ***
#                                 *****
#                                *******
#                               *********
#                              ***********
#                             *************
#                            ***************
#                           *****************
#                          *******************
#                         *********************
#                        ***********************
#                       *************************
#                      ***************************
#                     *****************************
#                    *******************************
#                   *********************************
#                  ***********************************
#                 *************************************
#                ***************************************
# ...

# %%
# n = 25
num = int(input("Calculating the factorial of: "))
factorial = 1
for i in range (1, num + 1):
    factorial *= i
print("The factorial of",num,"is",factorial)
# Out:
# Calculating the factorial of: 25
# The factorial of 25 is 15511210043330985984000000

# %% [markdown]
# ### *1.2: While loop syntax*

# %%
#While loop syntax
while some_condition:
  loop_body

# %% [markdown]
# While loop

# %%
result = 0
while n > 0:
  n = n // 10
  result += 1
print(result)

# %% [markdown]
# Fibonacci While loop

# %%
# n = 35
n = int(input("Printing the fibonacci numbers lower than: "))
a = 0
b = 1
while a <= n:
  print(a)
  c = a + b
  a = b
  b = c

# %% [markdown]
# Fibonacci - recursion

# %%
#Function for nth Fibonacci number

def Fibonacci(n):
    if n<= 0:
        print("Incorrect input")
    # First Fibonacci number is 0
    elif n == 1:
        return 0
    # Second Fibonacci number is 1
    elif n == 2:
        return 1
    else:
        return Fibonacci(n-1)+Fibonacci(n-2)

# Driver Program

print(Fibonacci(10))
# Out:
# 34

# %%
days = ["Monday", "Tuesday", "Wednesday", "Thursday","Friday", "Saturday", "Sunday"]
for day in days:
  print(day)
# Out:
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday

# %%
days = {"mon": "Monday", "tue": "Tuesday", "wed": "Wednesday", "thur": "Thursday","fri": "Friday", "sat": "Saturday", "sun": "Sunday"}
for day in days:
  print(day, "stands for", days[day])
# Out:
# mon stands for Monday
# tue stands for Tuesday
# wed stands for Wednesday
# thur stands for Thursday
# fri stands for Friday
# sat stands for Saturday
# sun stands for Sunday

# %% [markdown]
# Bitwise Operations

# %%
a = 10
b = 4

# Print bitwise AND operation
print("a & b =", a & b)
# Out:
# a & b = 0

# %%
a = 10
b = 4

# Print bitwise OR operation
print("a | b =", a | b)
# Out:
# a | b = 14

# %%
a = 10
b = 4

# print bitwise XOR operation
print("a ^ b =", a ^ b)
# Out:
# a ^ b = 14

# %%
a = 10
b = 4

# Print bitwise NOT operation
print("~a =", ~a)
# Out:
# ~a = -11

# %% [markdown]
# ###Python Bitwise Right Shift
#
# Shifts the bits of the number to the right and fills 0 on voids left( fills 1
#
# in the case of a negative number) as a result. Similar effect as of dividing
#
# the number with some power of two.
#
# ####Example 1:
#
# a = 10 = 0000 1010 (Binary)
#
# a >> 1 = 0000 0101 = 5
#
# ####Example 2:
#
# a = -10 = 1111 0110 (Binary)
#
# a >> 1 = 1111 1011 = -5

# %%
a = 10
b = -10
print("a equals:", a)
print("b equals:", b)
# print bitwise right shift operator
print("a >> 1 =", a >> 1)
print("b >> 1 =", b >> 1)
# Out:
# a equals: 10
# b equals: -10
# a >> 1 = 5
# b >> 1 = -5

# %% [markdown]
# ###Python Bitwise Left Shift
# Shifts the bits of the number to the left and fills 0 on voids right as a result. Similar effect as of multiplying the number with some power of two.
#
# ####Example 1:
#
# a = 5 = 0000 0101 (Binary)
#
# a << 1 = 0000 1010 = 10
#
# a << 2 = 0001 0100 = 20
#
# ####Example 2:
#
# b = -10 = 1111 0110 (Binary)
#
# b << 1 = 1110 1100 = -20
#
# b << 2 = 1101 1000 = -40

# %%
a = 5
b = -10
print("a equals:", a)
print("b equals:", b)
# print bitwise left shift operator
print("a << 1 =", a << 1)
print("b << 1 =", b << 1)
# Out:
# a equals: 5
# b equals: -10
# a << 1 = 10
# b << 1 = -20

# %%
# Python3 code to determine Length of
# longest consecutive zeroes in the
# binary representation of a number.
def isInteger(N):
  if isinstance(N, int):
    return True
  if isinstance(N, float):
    return N.is_integer()
  return False

def isInRange(N):
  if ((isInteger(N)) & (N >= 1) & (N <= 2147483647)):
    return True
  else:
    return False

def Solution(N):
    if ((isInteger(N)) & (N >= 1) & (N <= 2147483647)):
      print("The number N is in Range")
      return len(max(format(N, 'b').strip('0').split('1')))
    else:
      print("The number N is not in Range")
      return(0)

# Driver Code
#N = 32
N = int(input("Enter the number to find Max Zeroes: "))
print("is N an Integer? test 1", isInteger(N))
print("Max Zeroes for the binary:", bin(int(N)))
print(Solution(N))
# Out:
# Enter the number to find Max Zeroes: 10000
# is N an Integer? test 1 True
# Max Zeroes for the binary: 0b10011100010000
# The number N is in Range
# 3

# %%
#additional Code
 while(N):
        if(not(N & 1)):
            cnt += 1
            N >>= 1
            maxm = max(maxm,cnt)
        else:
            maxm = max(maxm,cnt)
            cnt = 0
            N >>= 1

    return maxm
