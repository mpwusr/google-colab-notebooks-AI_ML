# %%
x = 1 / 2 + 3 // 3 + 4 ** 2
print(x)
# Out:
# 17.5

# %%
x = 1
y = 2
z = x
x = y
y = z
print(x, y)
# Out:
# 2 1

# %%
x = 2
y = 4
x = x / y
y = y / x
print(y)
# Out:
# 8.0

# %%
1 // 2 * 3
# Out:
# 0

# %%
x = 11
y = 4
x = x % y
x = x % y
y = y % x
print(y)
# Out:
# 1
