# %%
1 + 3.4
# Out:
# 4.4

# %%
1 + "55"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-3c02fdfac4d2> in <cell line: 1>()
# ----> 1 1 + "55"
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
a = 10
b = 2.3
c = a*b
type(c)
# Out:
# float

# %%
i = '20'
if i > 20:
    print(1)
else:
    print(2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-babc5c5aa252> in <cell line: 2>()
#       1 i = '20'
# ----> 2 if i > 20:
#       3     print(1)
#       4 else:
#       5     print(2)
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
a = 1
for i in range(1,6):
     a = a*i
print(a)
# Out:
# 120

# %%
list = (5, 6, 7, 8)
print(list[-1])
print(list[-2])
print(list[3])
# Out:
# 8
# 7
# 8

# %%
alphabets = {'1':'A','2':'B','3': ['C','D','E']}
print(alphabets['3'][2])
# Out:
# E

# %%
list = ["Great", 51, True, 46, "Hi"]
list[2:-1]
# Out:
# [True, 46]

# %%
list_mul = ['2','2','2']
list_mul*2
# Out:
# ['2', '2', '2', '2', '2', '2']

# %%
def fun(n):
    return n*n*n
print(fun(5))
lambda_cube = lambda n: n*n*n
print(lambda_cube(5))
# Out:
# 125
# 125

# %%
def fun(n):
    return n*n*n
print(fun(5))
lambda_cube = lambda n: return n*n*n
print(lambda_cube(5))
# Out:
#   File "<ipython-input-21-1097bfba742e>", line 4
#     lambda_cube = lambda n: return n*n*n
#                             ^
# SyntaxError: invalid syntax
