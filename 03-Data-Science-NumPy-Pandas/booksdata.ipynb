# %%
import pandas as pd

# Read the CSV file
from google.colab import drive
drive.mount('/content/drive')
books_data = pd.read_csv("/content/drive/MyDrive/books.csv")

# View the first 5 rows
books_data.head()
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-3-5509997f874c> in <cell line: 5>()
#       3 # Read the CSV file
#       4 from google.colab import drive
# ----> 5 drive.mount('/content/drive')
#       6 books_data = pd.read_csv("/content/drive/MyDrive/books.csv")
#       7
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     135   )
#     136   if ephemeral:
# ...

# %%
numbers = [2, 3, 5, 4]
labels = ['lily', 'rose', 'daisy', 'lotus']
flowers = pd.Series(numbers, index=labels)
flowers['daisy']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-833c3a350541> in <cell line: 3>()
#       1 numbers = [2, 3, 5, 4]
#       2 labels = ['lily', 'rose', 'daisy', 'lotus']
# ----> 3 flowers = pd.Series(numbers, index=labels)
#       4 flowers['daisy']
#
# NameError: name 'pd' is not defined

# %%
books_data.shape
# Out:
# (5000, 10)

# %%
books_data.describe
# Out:
# <bound method NDFrame.describe of                                                   title  \
# 0                           The Hunchback of Notre-Dame
# 1     La Cucina Di Lidia: Recipes and Memories from ...
# 2                                     Breach of Promise
# 3                     Brief Interviews with Hideous Men
# 4     The Killing Dance (Anita Blake  Vampire Hunter...
# ...                                                 ...
# 4995                                 The Complete Works
# 4996                               Shipwreck (Island I)
# 4997           Every Night Italian: Every Night Italian
# 4998                                     Go Down  Moses
# 4999  The Avignon Quintet: Monsieur  Livia  Constanc...
#
#                            author  average_rating         isbn13  \
# 0                     Victor Hugo            4.00  9780345472427
# 1     Lidia Matticchio Bastianich            4.14  9780767914222
# ...

# %%
books_data.columns
# Out:
# Index(['title', 'author', 'average_rating', 'isbn13', 'language_code',
#        'num_pages', 'ratings_count', 'text_reviews_count', 'publisher',
#        'year'],
#       dtype='object')

# %%
books_data.dtypes
# Out:
# title                  object
# author                 object
# average_rating        float64
# isbn13                  int64
# language_code          object
# num_pages             float64
# ratings_count           int64
# text_reviews_count      int64
# publisher              object
# year                    int64
# dtype: object

# %%
books_data[(books_data.year == 2010)]
# Out:
#                                                   title  \
# 40    The Walking Dead  Book One (The Walking Dead #...
# 359        Things: A Story of the Sixties; A Man Asleep
# 425   The Gap Into Vision: Forbidden Knowledge (Gap ...
# 985                                     Never Let Me Go
# 1696           The Unexpected Guest: A Play In Two Acts
# 1789  A Short History of Nearly Everything (Illustra...
# 2620                                         The Client
# 2695                                      Lord of Light
# 2706         Pimsleur German Level 1 CD: [Lessons 1-30]
# 3079                             Tim Burton: Interviews
# 3724                                     Less Than Zero
# 4460                                     Riddley Walker
# 4650  The Beatles' Story on Capitol Records  Part Tw...
# 4891   Judy Moody Declares Independence (Judy Moody #6)
# 4914  Earthquake in the Early Morning (Magic Tree Ho...
#
# ...

# %%
books_data[(books_data.publisher == "DAW") & (books_data.average_rating>4)]
# Out:
#                                                title           author  \
# 71                           By the Sword (Valdemar)  Mercedes Lackey
# 871         Storm Rising (Valdemar: Mage Storms  #2)  Mercedes Lackey
# 1523       Phoenix and Ashes (Elemental Masters  #3)  Mercedes Lackey
# 1583  To Battle the Gods (Jalav  Amazon Warrior  #5)     Sharon Green
# 3726        Oathblood (Valdemar: Vows and Honor  #3)  Mercedes Lackey
# 4367                     Joust (Dragon Jousters  #1)  Mercedes Lackey
#
#       average_rating         isbn13 language_code  num_pages  ratings_count  \
# 71              4.25  9780886774639           eng      492.0          18531
# 871             4.02  9780886777128         en-US      412.0          10781
# 1523            4.01  9780756402723           eng      480.0           6980
# 1583            4.07  9780886771287           eng      446.0             87
# 3726            4.06  9780886777739         en-GB      394.0           9786
# ...

# %%
books_data[(books_data.num_pages > 500) & (books_data.year > 2010)]
# Out:
#                                                   title               author  \
# 2045  Billy Budd  Sailor and Other Uncompleted Writi...      Herman Melville
# 2775          Rick Steves' Europe Through the Back Door          Rick Steves
# 3075                                          The Iliad                Homer
# 3157                    George Washington's Sacred Fire    Peter A. Lillback
# 3546                                  The Will to Power  Friedrich Nietzsche
#
#       average_rating         isbn13 language_code  num_pages  ratings_count  \
# 2045            3.11  9780810111141           eng     1016.0              0
# 2775            4.24  9781566918084           eng      808.0           3569
# 3075            3.86  9781904633389           eng      542.0             64
# 3157            4.18  9780978605261           eng     1200.0            694
# 3546            4.05  9780394704371           eng      575.0           7931
#
# ...

# %%
books_data[(books_data.author == "Agatha Christie")]
# Out:
#                                                   title           author  \
# 809      One  Two  Buckle My Shoe (Hercule Poirot  #23)  Agatha Christie
# 850             A Murder Is Announced (Miss Marple  #5)  Agatha Christie
# 865     The Listerdale Mystery And Eleven Other Stories  Agatha Christie
# 969             Death on the Nile (Hercule Poirot  #17)  Agatha Christie
# 1021           Cards on the Table (Hercule Poirot  #15)  Agatha Christie
# 1396                           And Then There Were None  Agatha Christie
# 1433             Hallowe'en Party (Hercule Poirot  #39)  Agatha Christie
# 1448         Hickory Dickory Dock (Hercule Poirot  #32)  Agatha Christie
# 1696           The Unexpected Guest: A Play In Two Acts  Agatha Christie
# 2041      The Labours of Hercules (Hercule Poirot  #27)  Agatha Christie
# 2322                 Sleeping Murder (Miss Marple  #13)  Agatha Christie
# 2598           Evil Under the Sun (Hercule Poirot  #24)  Agatha Christie
# ...

# %%
books_data[(books_data.average_rating>4.5)&(books_data.ratings_count>10)]
# Out:
#                                                   title  \
# 13    Fire in the Minds of Men: Origins of the Revol...
# 35    The Lord of the Rings: The Art of the Fellowsh...
# 54    Collected Stories III: One Night in Brazil to ...
# 83    Collected Essays: Notes of a Native Son / Nobo...
# 200                                   Eva Hesse Drawing
# 334   The Price of the Ticket: Collected Nonfiction ...
# 457       The Shawshank Redemption: The Shooting Script
# 613   Nausicaä of the Valley of the Wind  Vol. 5 (Na...
# 650   The J.R.R. Tolkien Companion and Guide  Volume...
# 808           Lego Star Wars: Prima Official Game Guide
# 1000  The Fate of Reason: German Philosophy from Kan...
# 1008                                  The Complete Maus
# 1024                     A History of the Life Sciences
# 1033  The Valley of Vision: A Collection of Puritan ...
# 1057  The Power Broker: Robert Moses and the Fall of...
# 1079  Cook's Illustrated 1995 (Cook's Illustrated An...
# ...

# %%
books_data[(books_data.>4.5)&(books_data.ratings_count>10)]

# %%
books_data.loc[books_data['language_code'] == 'eng', 'average_rating'].mean()
# Out:
# 3.931142857142857

# %%
books_data.loc[:,'average_rating'].mean()
# Out:
# 3.9319319999999998

# %%
books_data.loc[:,'num_pages'].mean()
# Out:
# 341.0940205355345

# %%
books_data.loc[:,'num_pages'].max()
# Out:
# 3342.0

# %%
books_data.loc[:,'num_pages'].max()

# %%
books_data.loc[:,'num_pages'].mode()
# Out:
# 0    288.0
# Name: num_pages, dtype: float64

# %%
books_data.iloc[0:5,1:4]
# Out:
#                         author  average_rating         isbn13
# 0                  Victor Hugo            4.00  9780345472427
# 1  Lidia Matticchio Bastianich            4.14  9780767914222
# 2             James Scott Bell            4.00  9780310243878
# 3         David Foster Wallace            3.86  9780349111889
# 4          Laurell K. Hamilton            4.13  9780425209066

# %%
books_data.loc[[1,4],['language_code','num_pages','ratings_count']]
# Out:
#   language_code  num_pages  ratings_count
# 1         en-GB      288.0             48
# 4         en-US      368.0          59524

# %%
books_data[(books_data.language_code == "spa") & (books_data.year > 2000)]
# Out:
#                                                   title  \
# 21                      Los funerales de la Mamá Grande
# 53    La Emperatriz tras el velo (Trilogía Taj Mahal...
# 69                             La casa de los espíritus
# 93                                  Ya Sé Que Te Quiero
# 107                                 Secretos De Familia
# ...                                                 ...
# 4804                                      Muerte Blanca
# 4832  Entrevista con el vampiro (Crónicas vampíricas...
# 4890         Isabel: Princesa De Castilla  España  1466
# 4907                                     Ve  perro ¡Ve!
# 4951                                El librero de Kabul
#
#                       author  average_rating         isbn13 language_code  \
# 21    Gabriel García Márquez            3.78  9780307350329           spa
# 53           Indu Sundaresan            4.04  9788425337604           spa
# ...

# %%
books_data[(books_data.author == "Agatha Christie")]
# Out:
#                                                   title           author  \
# 809      One  Two  Buckle My Shoe (Hercule Poirot  #23)  Agatha Christie
# 850             A Murder Is Announced (Miss Marple  #5)  Agatha Christie
# 865     The Listerdale Mystery And Eleven Other Stories  Agatha Christie
# 969             Death on the Nile (Hercule Poirot  #17)  Agatha Christie
# 1021           Cards on the Table (Hercule Poirot  #15)  Agatha Christie
# 1396                           And Then There Were None  Agatha Christie
# 1433             Hallowe'en Party (Hercule Poirot  #39)  Agatha Christie
# 1448         Hickory Dickory Dock (Hercule Poirot  #32)  Agatha Christie
# 1696           The Unexpected Guest: A Play In Two Acts  Agatha Christie
# 2041      The Labours of Hercules (Hercule Poirot  #27)  Agatha Christie
# 2322                 Sleeping Murder (Miss Marple  #13)  Agatha Christie
# 2598           Evil Under the Sun (Hercule Poirot  #24)  Agatha Christie
# ...
